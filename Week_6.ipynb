# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments-WEEK6/blob/main/Week_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# 1. Import math

# FUNCTION DEFINITIONS
# 1. Define area(radius): returns pi * r squared
# 2. Define circumference(radius): returns 2 * pi * r
# 3. Define volume(radius, height):
#    - Call area(radius)
#    - Multiply result by height
#    - Return result

# PROGRAM LOGIC
# 1. Ask user for radius
# 2. Call and print area
# 3. Call and print circumference
# 4. Ask user for height
# 5. Call and print volume
